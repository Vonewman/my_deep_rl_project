# %% [markdown]
# <a href="https://colab.research.google.com/github/Vonewman/my_deep_rl_project/blob/master/predictor_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing libraries

# %%
## importing libraries
import pandas as pd
import numpy as np
import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Dense, Dropout
from keras.models import Sequential
from keras.optimizers import Adam

# %% [markdown]
# ## Importing the dataset

# %%
## importing the dataset
dataset = pd.read_csv('kc_house_data.csv')

# %%
dataset
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %% [markdown]
# ## Getting separately the features and the targets

# %%
# Getting separately the features and the targets
X = dataset.iloc[:, 3:].values
X = X[:, np.r_[0:13,14:18]]
y = dataset.iloc[:, 2].values

# %% [markdown]
# # Data Preparation

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Scaling data

# %%
# Scaling the features
xscaler = MinMaxScaler(feature_range = (0,1))
X_train = xscaler.fit_transform(X_train)
X_test = xscaler.transform(X_test)

# Scaling the target
yscaler = MinMaxScaler(feature_range = (0,1))
y_train = yscaler.fit_transform(y_train.reshape(-1,1))
y_test  = yscaler.transform(y_test.reshape(-1,1))

# %% [markdown]
# # Building the Neural Network

# %%
## Building the Artificial Neural Network
model = Sequential()
model.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu', input_dim = 17))
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 1, kernel_initializer  = 'uniform', activation = 'relu'))
model.compile(optimizer = Adam(lr = 0.001), loss = 'mse', metrics = ['mean_absolute_error'])

# %% [markdown]
# ## Training the neural network

# %%
# Training the Artificial Neural Network
model.fit(X_train, y_train, batch_size = 32, epochs = 100, validation_data = (X_test, y_test))
# Out:
# Train on 17290 samples, validate on 4323 samples
# Epoch 1/100
# 17290/17290 [==============================] - 1s 58us/step - loss: 0.0011 - mean_absolute_error: 0.0200 - val_loss: 6.2769e-04 - val_mean_absolute_error: 0.0164
# Epoch 2/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 6.4034e-04 - mean_absolute_error: 0.0158 - val_loss: 5.2263e-04 - val_mean_absolute_error: 0.0139
# Epoch 3/100
# 17290/17290 [==============================] - 1s 42us/step - loss: 5.8664e-04 - mean_absolute_error: 0.0150 - val_loss: 5.0002e-04 - val_mean_absolute_error: 0.0144
# Epoch 4/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 5.3280e-04 - mean_absolute_error: 0.0142 - val_loss: 4.4736e-04 - val_mean_absolute_error: 0.0129
# Epoch 5/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 5.0070e-04 - mean_absolute_error: 0.0136 - val_loss: 4.1996e-04 - val_mean_absolute_error: 0.0126
# Epoch 6/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 4.6564e-04 - mean_absolute_error: 0.0132 - val_loss: 3.8842e-04 - val_mean_absolute_error: 0.0117
# Epoch 7/100
# 17290/17290 [==============================] - 1s 42us/step - loss: 4.5099e-04 - mean_absolute_error: 0.0129 - val_loss: 4.2963e-04 - val_mean_absolute_error: 0.0127
# Epoch 8/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 4.2495e-04 - mean_absolute_error: 0.0125 - val_loss: 3.4634e-04 - val_mean_absolute_error: 0.0112
# Epoch 9/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 4.1655e-04 - mean_absolute_error: 0.0125 - val_loss: 4.6783e-04 - val_mean_absolute_error: 0.0156
# Epoch 10/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 3.9605e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1969e-04 - val_mean_absolute_error: 0.0107
# Epoch 11/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 3.8176e-04 - mean_absolute_error: 0.0121 - val_loss: 3.3965e-04 - val_mean_absolute_error: 0.0113
# Epoch 12/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 3.8604e-04 - mean_absolute_error: 0.0120 - val_loss: 3.1819e-04 - val_mean_absolute_error: 0.0111
# Epoch 13/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 3.6974e-04 - mean_absolute_error: 0.0117 - val_loss: 3.5231e-04 - val_mean_absolute_error: 0.0110
# Epoch 14/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 3.6330e-04 - mean_absolute_error: 0.0117 - val_loss: 3.0454e-04 - val_mean_absolute_error: 0.0106
# Epoch 15/100
# 17290/17290 [==============================] - 1s 41us/step - loss: 3.5541e-04 - mean_absolute_error: 0.0114 - val_loss: 3.6373e-04 - val_mean_absolute_error: 0.0119
# Epoch 16/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 3.5661e-04 - mean_absolute_error: 0.0115 - val_loss: 3.1832e-04 - val_mean_absolute_error: 0.0107
# Epoch 17/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 3.4492e-04 - mean_absolute_error: 0.0115 - val_loss: 3.0955e-04 - val_mean_absolute_error: 0.0104
# Epoch 18/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 3.4112e-04 - mean_absolute_error: 0.0113 - val_loss: 2.9830e-04 - val_mean_absolute_error: 0.0105
# Epoch 19/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 3.2852e-04 - mean_absolute_error: 0.0112 - val_loss: 3.0805e-04 - val_mean_absolute_error: 0.0108
# Epoch 20/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 3.2390e-04 - mean_absolute_error: 0.0111 - val_loss: 2.9065e-04 - val_mean_absolute_error: 0.0104
# Epoch 21/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 3.2548e-04 - mean_absolute_error: 0.0111 - val_loss: 3.5027e-04 - val_mean_absolute_error: 0.0111
# Epoch 22/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 3.2648e-04 - mean_absolute_error: 0.0111 - val_loss: 3.1761e-04 - val_mean_absolute_error: 0.0112
# Epoch 23/100
# 17290/17290 [==============================] - 1s 41us/step - loss: 3.2134e-04 - mean_absolute_error: 0.0110 - val_loss: 3.0861e-04 - val_mean_absolute_error: 0.0101
# Epoch 24/100
# 17290/17290 [==============================] - 1s 43us/step - loss: 3.2658e-04 - mean_absolute_error: 0.0111 - val_loss: 3.1353e-04 - val_mean_absolute_error: 0.0102
# Epoch 25/100
# 17290/17290 [==============================] - 1s 44us/step - loss: 3.0903e-04 - mean_absolute_error: 0.0108 - val_loss: 2.9727e-04 - val_mean_absolute_error: 0.0110
# Epoch 26/100
# 17290/17290 [==============================] - 1s 43us/step - loss: 3.2457e-04 - mean_absolute_error: 0.0112 - val_loss: 2.8144e-04 - val_mean_absolute_error: 0.0101
# Epoch 27/100
# 17290/17290 [==============================] - 1s 43us/step - loss: 3.0974e-04 - mean_absolute_error: 0.0109 - val_loss: 2.7435e-04 - val_mean_absolute_error: 0.0100
# Epoch 28/100
# 17290/17290 [==============================] - 1s 43us/step - loss: 3.0264e-04 - mean_absolute_error: 0.0108 - val_loss: 3.0059e-04 - val_mean_absolute_error: 0.0104
# Epoch 29/100
# 17290/17290 [==============================] - 1s 42us/step - loss: 3.0892e-04 - mean_absolute_error: 0.0109 - val_loss: 2.8485e-04 - val_mean_absolute_error: 0.0103
# Epoch 30/100
# 17290/17290 [==============================] - 1s 44us/step - loss: 3.0424e-04 - mean_absolute_error: 0.0108 - val_loss: 2.8582e-04 - val_mean_absolute_error: 0.0101
# Epoch 31/100
# 17290/17290 [==============================] - 1s 43us/step - loss: 3.0021e-04 - mean_absolute_error: 0.0108 - val_loss: 2.6903e-04 - val_mean_absolute_error: 0.0098
# Epoch 32/100
# 17290/17290 [==============================] - 1s 43us/step - loss: 2.9997e-04 - mean_absolute_error: 0.0108 - val_loss: 2.8599e-04 - val_mean_absolute_error: 0.0105
# Epoch 33/100
# 17290/17290 [==============================] - 1s 44us/step - loss: 2.9269e-04 - mean_absolute_error: 0.0106 - val_loss: 2.7161e-04 - val_mean_absolute_error: 0.0098
# Epoch 34/100
# 17290/17290 [==============================] - 1s 43us/step - loss: 3.1761e-04 - mean_absolute_error: 0.0110 - val_loss: 2.7748e-04 - val_mean_absolute_error: 0.0099
# Epoch 35/100
# 17290/17290 [==============================] - 1s 42us/step - loss: 2.8869e-04 - mean_absolute_error: 0.0106 - val_loss: 2.7114e-04 - val_mean_absolute_error: 0.0099
# Epoch 36/100
# 17290/17290 [==============================] - 1s 41us/step - loss: 2.9000e-04 - mean_absolute_error: 0.0107 - val_loss: 2.7371e-04 - val_mean_absolute_error: 0.0099
# Epoch 37/100
# 17290/17290 [==============================] - 1s 43us/step - loss: 3.0319e-04 - mean_absolute_error: 0.0108 - val_loss: 2.9992e-04 - val_mean_absolute_error: 0.0107
# Epoch 38/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.9360e-04 - mean_absolute_error: 0.0107 - val_loss: 2.7282e-04 - val_mean_absolute_error: 0.0097
# Epoch 39/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.8844e-04 - mean_absolute_error: 0.0106 - val_loss: 2.6543e-04 - val_mean_absolute_error: 0.0097
# Epoch 40/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.9839e-04 - mean_absolute_error: 0.0107 - val_loss: 3.1151e-04 - val_mean_absolute_error: 0.0108
# Epoch 41/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.8506e-04 - mean_absolute_error: 0.0106 - val_loss: 3.0905e-04 - val_mean_absolute_error: 0.0100
# Epoch 42/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.9963e-04 - mean_absolute_error: 0.0107 - val_loss: 2.8329e-04 - val_mean_absolute_error: 0.0101
# Epoch 43/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.8485e-04 - mean_absolute_error: 0.0105 - val_loss: 3.0544e-04 - val_mean_absolute_error: 0.0101
# Epoch 44/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.8824e-04 - mean_absolute_error: 0.0106 - val_loss: 2.6895e-04 - val_mean_absolute_error: 0.0100
# Epoch 45/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.8974e-04 - mean_absolute_error: 0.0106 - val_loss: 2.9722e-04 - val_mean_absolute_error: 0.0102
# Epoch 46/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 2.7778e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7745e-04 - val_mean_absolute_error: 0.0101
# Epoch 47/100
# 17290/17290 [==============================] - 1s 41us/step - loss: 2.8623e-04 - mean_absolute_error: 0.0106 - val_loss: 2.8409e-04 - val_mean_absolute_error: 0.0098
# Epoch 48/100
# 17290/17290 [==============================] - 1s 42us/step - loss: 2.8156e-04 - mean_absolute_error: 0.0105 - val_loss: 2.9071e-04 - val_mean_absolute_error: 0.0107
# Epoch 49/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 2.8146e-04 - mean_absolute_error: 0.0104 - val_loss: 2.6595e-04 - val_mean_absolute_error: 0.0097
# Epoch 50/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.7677e-04 - mean_absolute_error: 0.0104 - val_loss: 2.6185e-04 - val_mean_absolute_error: 0.0096
# Epoch 51/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.8108e-04 - mean_absolute_error: 0.0104 - val_loss: 2.7610e-04 - val_mean_absolute_error: 0.0096
# Epoch 52/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.7348e-04 - mean_absolute_error: 0.0103 - val_loss: 2.5957e-04 - val_mean_absolute_error: 0.0096
# Epoch 53/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.7251e-04 - mean_absolute_error: 0.0103 - val_loss: 2.6622e-04 - val_mean_absolute_error: 0.0098
# Epoch 54/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.7987e-04 - mean_absolute_error: 0.0104 - val_loss: 3.3095e-04 - val_mean_absolute_error: 0.0112
# Epoch 55/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.7380e-04 - mean_absolute_error: 0.0104 - val_loss: 2.6521e-04 - val_mean_absolute_error: 0.0097
# Epoch 56/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.7251e-04 - mean_absolute_error: 0.0103 - val_loss: 2.6536e-04 - val_mean_absolute_error: 0.0095
# Epoch 57/100
# 17290/17290 [==============================] - 1s 41us/step - loss: 2.7694e-04 - mean_absolute_error: 0.0104 - val_loss: 2.6134e-04 - val_mean_absolute_error: 0.0096
# Epoch 58/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.6403e-04 - mean_absolute_error: 0.0102 - val_loss: 2.6670e-04 - val_mean_absolute_error: 0.0096
# Epoch 59/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.6089e-04 - mean_absolute_error: 0.0102 - val_loss: 3.0379e-04 - val_mean_absolute_error: 0.0103
# Epoch 60/100
# 17290/17290 [==============================] - 1s 42us/step - loss: 2.7397e-04 - mean_absolute_error: 0.0103 - val_loss: 2.6702e-04 - val_mean_absolute_error: 0.0098
# Epoch 61/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.7330e-04 - mean_absolute_error: 0.0103 - val_loss: 2.9986e-04 - val_mean_absolute_error: 0.0104
# Epoch 62/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.6904e-04 - mean_absolute_error: 0.0102 - val_loss: 2.5581e-04 - val_mean_absolute_error: 0.0097
# Epoch 63/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.6675e-04 - mean_absolute_error: 0.0103 - val_loss: 3.2390e-04 - val_mean_absolute_error: 0.0109
# Epoch 64/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.6892e-04 - mean_absolute_error: 0.0103 - val_loss: 2.8159e-04 - val_mean_absolute_error: 0.0103
# Epoch 65/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.6194e-04 - mean_absolute_error: 0.0102 - val_loss: 2.6735e-04 - val_mean_absolute_error: 0.0099
# Epoch 66/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.6249e-04 - mean_absolute_error: 0.0102 - val_loss: 2.6636e-04 - val_mean_absolute_error: 0.0098
# Epoch 67/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.6346e-04 - mean_absolute_error: 0.0101 - val_loss: 2.8378e-04 - val_mean_absolute_error: 0.0096
# Epoch 68/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.7455e-04 - mean_absolute_error: 0.0104 - val_loss: 2.6604e-04 - val_mean_absolute_error: 0.0097
# Epoch 69/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 2.6655e-04 - mean_absolute_error: 0.0102 - val_loss: 2.7320e-04 - val_mean_absolute_error: 0.0098
# Epoch 70/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 2.6282e-04 - mean_absolute_error: 0.0101 - val_loss: 2.7568e-04 - val_mean_absolute_error: 0.0103
# Epoch 71/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.6077e-04 - mean_absolute_error: 0.0101 - val_loss: 3.1390e-04 - val_mean_absolute_error: 0.0113
# Epoch 72/100
# 17290/17290 [==============================] - 1s 42us/step - loss: 2.6235e-04 - mean_absolute_error: 0.0101 - val_loss: 2.9428e-04 - val_mean_absolute_error: 0.0096
# Epoch 73/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.6889e-04 - mean_absolute_error: 0.0102 - val_loss: 2.6618e-04 - val_mean_absolute_error: 0.0099
# Epoch 74/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 2.5670e-04 - mean_absolute_error: 0.0100 - val_loss: 2.7466e-04 - val_mean_absolute_error: 0.0099
# Epoch 75/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.5679e-04 - mean_absolute_error: 0.0100 - val_loss: 2.8477e-04 - val_mean_absolute_error: 0.0103
# Epoch 76/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 2.5912e-04 - mean_absolute_error: 0.0101 - val_loss: 2.5852e-04 - val_mean_absolute_error: 0.0096
# Epoch 77/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 2.5368e-04 - mean_absolute_error: 0.0100 - val_loss: 2.7879e-04 - val_mean_absolute_error: 0.0102
# Epoch 78/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.6091e-04 - mean_absolute_error: 0.0101 - val_loss: 2.5624e-04 - val_mean_absolute_error: 0.0098
# Epoch 79/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.5876e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5800e-04 - val_mean_absolute_error: 0.0095
# Epoch 80/100
# 17290/17290 [==============================] - 1s 43us/step - loss: 2.5402e-04 - mean_absolute_error: 0.0099 - val_loss: 2.5660e-04 - val_mean_absolute_error: 0.0094
# Epoch 81/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 2.5911e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5042e-04 - val_mean_absolute_error: 0.0094
# Epoch 82/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.5039e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5300e-04 - val_mean_absolute_error: 0.0101
# Epoch 83/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.4969e-04 - mean_absolute_error: 0.0099 - val_loss: 2.4426e-04 - val_mean_absolute_error: 0.0094
# Epoch 84/100
# 17290/17290 [==============================] - 1s 41us/step - loss: 2.4658e-04 - mean_absolute_error: 0.0099 - val_loss: 2.6139e-04 - val_mean_absolute_error: 0.0094
# Epoch 85/100
# 17290/17290 [==============================] - 1s 43us/step - loss: 2.5772e-04 - mean_absolute_error: 0.0100 - val_loss: 3.3133e-04 - val_mean_absolute_error: 0.0118
# Epoch 86/100
# 17290/17290 [==============================] - 1s 37us/step - loss: 2.4543e-04 - mean_absolute_error: 0.0099 - val_loss: 2.7225e-04 - val_mean_absolute_error: 0.0094
# Epoch 87/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.5460e-04 - mean_absolute_error: 0.0100 - val_loss: 2.4696e-04 - val_mean_absolute_error: 0.0095
# Epoch 88/100
# 17290/17290 [==============================] - 1s 43us/step - loss: 2.5330e-04 - mean_absolute_error: 0.0099 - val_loss: 2.5397e-04 - val_mean_absolute_error: 0.0095
# Epoch 89/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.4098e-04 - mean_absolute_error: 0.0098 - val_loss: 2.7538e-04 - val_mean_absolute_error: 0.0098
# Epoch 90/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.5064e-04 - mean_absolute_error: 0.0100 - val_loss: 2.9097e-04 - val_mean_absolute_error: 0.0107
# Epoch 91/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.4804e-04 - mean_absolute_error: 0.0099 - val_loss: 2.4658e-04 - val_mean_absolute_error: 0.0094
# Epoch 92/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.4973e-04 - mean_absolute_error: 0.0100 - val_loss: 3.1989e-04 - val_mean_absolute_error: 0.0128
# Epoch 93/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.4005e-04 - mean_absolute_error: 0.0098 - val_loss: 2.7529e-04 - val_mean_absolute_error: 0.0103
# Epoch 94/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.4794e-04 - mean_absolute_error: 0.0099 - val_loss: 2.5432e-04 - val_mean_absolute_error: 0.0097
# Epoch 95/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.4850e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5675e-04 - val_mean_absolute_error: 0.0098
# Epoch 96/100
# 17290/17290 [==============================] - 1s 40us/step - loss: 2.4027e-04 - mean_absolute_error: 0.0098 - val_loss: 3.0207e-04 - val_mean_absolute_error: 0.0104
# Epoch 97/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.4307e-04 - mean_absolute_error: 0.0098 - val_loss: 2.5657e-04 - val_mean_absolute_error: 0.0096
# Epoch 98/100
# 17290/17290 [==============================] - 1s 38us/step - loss: 2.4246e-04 - mean_absolute_error: 0.0098 - val_loss: 2.6812e-04 - val_mean_absolute_error: 0.0096
# Epoch 99/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.4705e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5808e-04 - val_mean_absolute_error: 0.0093
# Epoch 100/100
# 17290/17290 [==============================] - 1s 39us/step - loss: 2.4365e-04 - mean_absolute_error: 0.0098 - val_loss: 2.4407e-04 - val_mean_absolute_error: 0.0093

# %% [markdown]
# ## Displaying results

# %%
## Making predictions on the test set while reversing the scaling
y_test = yscaler.inverse_transform(y_test)
prediction = yscaler.inverse_transform(model.predict(X_test))

# %%
# Computing the error rate
error = abs(prediction - y_test)/y_test
print(np.mean(error))
# Out:
# 0.1377944117407369
